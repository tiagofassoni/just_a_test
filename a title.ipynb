# %%
import pandas as pd

# %%
df_jan_2019 = pd.read_csv('flight-delay-prediction/Jan_2019_ontime.csv')

# %%
df_jan_2020 = pd.read_csv('flight-delay-prediction/Jan_2020_ontime.csv')

# %%
df_jan_2019
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
df_jan_2020
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            3                EV                  20366
# 1                  1            3                EV                  20366
# 2                  1            3                EV                  20366
# 3                  1            3                EV                  20366
# 4                  1            3                EV                  20366
# ...              ...          ...               ...                    ...
# 607341            31            5                9E                  20363
# 607342            31            5                9E                  20363
# 607343            31            5                9E                  20363
# 607344            31            5                9E                  20363
# 607345            31            5                9E                  20363
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
df_jan_2019["ORIGIN"].value_counts().head(20).plot.bar(title='Busiest Airports 2019')

# %%
df_jan_2020["ORIGIN"].value_counts().head(20).plot.bar(title='Busiest Airports 2020')
